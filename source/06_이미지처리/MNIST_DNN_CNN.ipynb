# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.datasets import mnist # mnist 훈련셋과 테스트셋
from tensorflow.keras.utils import to_categorical # 원핫인코딩
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from matplotlib import pyplot as plt # 학습과정 loss와 acc 시각화

# %%
# 1. 데이터 셋
width = 28; height=28
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
plt_row = 3
plt_col = 10
# plt.figure(figsize=(plt_col, plt_row))
plt.rcParams['figure.figsize'] = [plt_col, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
# axes[0, 0].imshow(X_test[0].reshape(width, height))
# axes[0, 0].axis('off')
# title = "실제:{}".format(y_test[0])
# axes[0, 0].set_title(title)
plt.subplots_adjust(hspace=0.4, wspace=0.3)
for i in range(plt_row*plt_col):
    subax = axes[i//plt_col, i%plt_col] # //:몫연산자 %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "실제:{}".format(y_test[i])
    subax.set_title(title)
#plt.tight_layout()

# %% [markdown]
# # 1. DNN

# %%
# %%time
# 1. 데이터 생성 및 전처리
width=28; height=28
(X_train, y_train), (X_test, y_test)= mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width*height).astype('float32')/255.0
X_val = X_val.reshape(-1, width*height).astype('float32')/255.0
X_test = X_test.reshape(-1, width*height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape

# 2. 모델 구성
model = Sequential([
    Input(shape=(width*height,)),
    Dense(units=1024, activation='relu'),
    Dropout(0.3),
    Dense(units=512, activation='relu'),
    Dropout(0.3),
    Dense(units=256, activation='relu'),
    Dropout(0.2),
    Dense(units=10, activation='softmax')
])
# model.summary()
# 3. 학습설정
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 4. 학습
model.fit(X_train, Y_train,
         epochs=50,
         validation_data=(X_val, Y_val),
         verbose=1)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.2708 - accuracy: 0.9174 - val_loss: 0.1139 - val_accuracy: 0.9659
# Epoch 2/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.1410 - accuracy: 0.9579 - val_loss: 0.0927 - val_accuracy: 0.9731
# Epoch 3/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.1133 - accuracy: 0.9667 - val_loss: 0.0807 - val_accuracy: 0.9781
# Epoch 4/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0946 - accuracy: 0.9715 - val_loss: 0.0900 - val_accuracy: 0.9744
# Epoch 5/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0817 - accuracy: 0.9758 - val_loss: 0.0815 - val_accuracy: 0.9759
# Epoch 6/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0764 - accuracy: 0.9770 - val_loss: 0.0903 - val_accuracy: 0.9768
# Epoch 7/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0688 - accuracy: 0.9799 - val_loss: 0.1060 - val_accuracy: 0.9733
# Epoch 8/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0654 - accuracy: 0.9813 - val_loss: 0.0814 - val_accuracy: 0.9788
# Epoch 9/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0594 - accuracy: 0.9836 - val_loss: 0.0865 - val_accuracy: 0.9820
# Epoch 10/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0579 - accuracy: 0.9835 - val_loss: 0.0904 - val_accuracy: 0.9791
# Epoch 11/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0541 - accuracy: 0.9845 - val_loss: 0.0949 - val_accuracy: 0.9800
# Epoch 12/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0499 - accuracy: 0.9854 - val_loss: 0.0982 - val_accuracy: 0.9814
# Epoch 13/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0535 - accuracy: 0.9854 - val_loss: 0.1038 - val_accuracy: 0.9802
# Epoch 14/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0465 - accuracy: 0.9868 - val_loss: 0.0975 - val_accuracy: 0.9805
# Epoch 15/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0496 - accuracy: 0.9860 - val_loss: 0.0932 - val_accuracy: 0.9816
# Epoch 16/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0452 - accuracy: 0.9880 - val_loss: 0.0973 - val_accuracy: 0.9819
# Epoch 17/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0497 - accuracy: 0.9869 - val_loss: 0.1003 - val_accuracy: 0.9810
# Epoch 18/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0388 - accuracy: 0.9893 - val_loss: 0.1007 - val_accuracy: 0.9832
# Epoch 19/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0431 - accuracy: 0.9887 - val_loss: 0.1043 - val_accuracy: 0.9814
# Epoch 20/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0397 - accuracy: 0.9892 - val_loss: 0.0998 - val_accuracy: 0.9822
# Epoch 21/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0390 - accuracy: 0.9898 - val_loss: 0.0986 - val_accuracy: 0.9835
# Epoch 22/50
# 1563/1563 [==============================] - 17s 11ms/step - loss: 0.0376 - accuracy: 0.9900 - val_loss: 0.1331 - val_accuracy: 0.9800
# Epoch 23/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0399 - accuracy: 0.9895 - val_loss: 0.1103 - val_accuracy: 0.9820
# Epoch 24/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0403 - accuracy: 0.9897 - val_loss: 0.1339 - val_accuracy: 0.9809
# Epoch 25/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0373 - accuracy: 0.9908 - val_loss: 0.1195 - val_accuracy: 0.9813
# Epoch 26/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0437 - accuracy: 0.9899 - val_loss: 0.1103 - val_accuracy: 0.9821
# Epoch 27/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0355 - accuracy: 0.9912 - val_loss: 0.1264 - val_accuracy: 0.9812
# Epoch 28/50
# 1563/1563 [==============================] - 18s 11ms/step - loss: 0.0378 - accuracy: 0.9914 - val_loss: 0.1299 - val_accuracy: 0.9821
# Epoch 29/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0367 - accuracy: 0.9913 - val_loss: 0.1257 - val_accuracy: 0.9820
# Epoch 30/50
# 1563/1563 [==============================] - 20s 12ms/step - loss: 0.0413 - accuracy: 0.9905 - val_loss: 0.1253 - val_accuracy: 0.9821
# Epoch 31/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0365 - accuracy: 0.9915 - val_loss: 0.1629 - val_accuracy: 0.9808
# Epoch 32/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0358 - accuracy: 0.9919 - val_loss: 0.1152 - val_accuracy: 0.9828
# Epoch 33/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0357 - accuracy: 0.9914 - val_loss: 0.1184 - val_accuracy: 0.9833
# Epoch 34/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0350 - accuracy: 0.9915 - val_loss: 0.1392 - val_accuracy: 0.9826
# Epoch 35/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0361 - accuracy: 0.9921 - val_loss: 0.1451 - val_accuracy: 0.9826
# Epoch 36/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0382 - accuracy: 0.9915 - val_loss: 0.1584 - val_accuracy: 0.9824
# Epoch 37/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0338 - accuracy: 0.9919 - val_loss: 0.1584 - val_accuracy: 0.9830
# Epoch 38/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0338 - accuracy: 0.9924 - val_loss: 0.1449 - val_accuracy: 0.9814
# Epoch 39/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0396 - accuracy: 0.9920 - val_loss: 0.1493 - val_accuracy: 0.9826
# Epoch 40/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0339 - accuracy: 0.9929 - val_loss: 0.1505 - val_accuracy: 0.9835
# Epoch 41/50
# 1563/1563 [==============================] - 21s 13ms/step - loss: 0.0354 - accuracy: 0.9923 - val_loss: 0.1320 - val_accuracy: 0.9827
# Epoch 42/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0363 - accuracy: 0.9926 - val_loss: 0.1624 - val_accuracy: 0.9809
# Epoch 43/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0289 - accuracy: 0.9934 - val_loss: 0.1635 - val_accuracy: 0.9811
# Epoch 44/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0404 - accuracy: 0.9919 - val_loss: 0.1361 - val_accuracy: 0.9817
# Epoch 45/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0355 - accuracy: 0.9927 - val_loss: 0.1502 - val_accuracy: 0.9831
# Epoch 46/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0321 - accuracy: 0.9932 - val_loss: 0.1557 - val_accuracy: 0.9827
# Epoch 47/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0308 - accuracy: 0.9934 - val_loss: 0.1652 - val_accuracy: 0.9828
# Epoch 48/50
# 1563/1563 [==============================] - 20s 13ms/step - loss: 0.0307 - accuracy: 0.9937 - val_loss: 0.1512 - val_accuracy: 0.9824
# Epoch 49/50
# 1563/1563 [==============================] - 19s 12ms/step - loss: 0.0335 - accuracy: 0.9934 - val_loss: 0.1513 - val_accuracy: 0.9844
# Epoch 50/50
# 1563/1563 [==============================] - 18s 12ms/step - loss: 0.0325 - accuracy: 0.9935 - val_loss: 0.1565 - val_accuracy: 0.9833
# CPU times: total: 1h 6min 51s
# Wall time: 15min 46s

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1654 - accuracy: 0.9829
# [0.16540038585662842, 0.9829000234603882]

# %%
# 혼동행렬
from sklearn.metrics import confusion_matrix
print('실제값 :', y_test)
print('실제값 :', np.argmax(Y_test, axis=1))
yhat = model.predict(X_test).argmax(axis=1)
cmatrix = confusion_matrix(y_test, yhat)
cmatrix
# Out:
# 실제값 : [7 2 1 ... 4 5 6]
# 실제값 : [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 1s 4ms/step
# array([[ 971,    1,    1,    0,    1,    0,    2,    2,    2,    0],
#        [   0, 1120,    1,    2,    0,    2,    1,    0,    9,    0],
#        [   3,    0, 1009,    1,    1,    0,    4,    8,    6,    0],
#        [   1,    0,    1,  997,    0,    2,    0,    3,    2,    4],
#        [   0,    0,    2,    1,  962,    0,    4,    0,    0,   13],
#        [   2,    0,    0,    6,    1,  876,    4,    0,    2,    1],
#        [   4,    2,    0,    0,    1,    2,  947,    0,    2,    0],
#        [   0,    1,    6,    3,    0,    0,    0, 1008,    7,    3],
#        [   2,    0,    3,    7,    3,    6,    1,    4,  946,    2],
#        [   0,    2,    0,    2,    4,    2,    1,    4,    1,  993]],
#       dtype=int64)

# %%
# 실제값과 예측값이 다른 갯수(방법1)
cnt = 0
for i, row in enumerate(cmatrix):
    for j, data in enumerate(row):
        if i!=j:
            cnt += data
print('예측이 틀린 갯수 :', cnt)
# Out:
# 예측이 틀린 갯수 : 171

# %%
# CNN을 사용하여 예측이 틀린 데이터 출력(yhat과 y_test가 다른 것들 172개)
plt_row = 18
plt_col = 10
plt.rcParams['figure.figsize'] = [plt_col+3, plt_row]
plt.rc("font", family="Malgun Gothic") # window에서 한글 시각화
# plt.rc("font", family="NanumBarunGothic") # 코랩에서 한글 시각화
fig, axes = plt.subplots(plt_row, plt_col)
plt.subplots_adjust(hspace=0.4, wspace=0.3)

i=0 # yhat과 y_test의 index => yhat[i], y_test[i]를 비교. 
cnt=0 # 이미지 출력횟수

while (i<len(y_test)) & (cnt < plt_row*plt_col):
    if yhat[i] == y_test[i]:
        i += 1
        continue
    subax = axes[cnt//plt_col, cnt%plt_col] # //:몫연산자 %:나머지연산자
    subax.imshow(X_test[i].reshape(width, height))
    subax.axis('off')
    title = "y{}/h{}({})".format(y_test[i], yhat[i], i)
    subax.set_title(title)
    cnt += 1 # 이미지 출력 번호 증가
    i += 1 # index 증가
#plt.tight_layout()

# %% [markdown]
# # CNN(컨볼루션 레이어 포함) - 교안 31page

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils    import to_categorical
from tensorflow.keras.models   import Sequential, save_model, load_model
from tensorflow.keras.layers   import Input, Conv2D, MaxPool2D, Flatten, Dropout, Dense
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix

# %%
# 1. 데이터 생성 및 전처리
width=28; height=28
(X_train, y_train), (X_test, y_test)= mnist.load_data()
X_val = X_train[50000:]
y_val = y_train[50000:]
X_train = X_train[:50000]
y_train = y_train[:50000]
# 독립변수 (28,28) => 784 1차원 -> 실수형변환 -> 스케일조정
X_train = X_train.reshape(-1, width, height).astype('float32')/255.0
X_val = X_val.reshape(-1, width, height).astype('float32')/255.0
X_test = X_test.reshape(-1, width, height).astype('float32')/255.0
# 타겟변수 원핫인코딩
Y_train = to_categorical(y_train)
Y_val = to_categorical(y_val)
Y_test = to_categorical(y_test)

X_train.shape, Y_train.shape, X_val.shape, Y_val.shape, X_test.shape, Y_test.shape
# Out:
# ((50000, 28, 28),
#  (50000, 10),
#  (10000, 28, 28),
#  (10000, 10),
#  (10000, 28, 28),
#  (10000, 10))

# %%
# 2. 모델생성
model = Sequential()
model.add(Conv2D(filters=32, #  필터수
                 kernel_size=3,# 필터사이즈 (3,3)
                 padding='same', # zero-padding을 하면 출력사이즈도 동일
                 input_shape=(width, height, 1), # 입력채널1개, 필터32 => 28*28*32채널 출력
                 activation='relu'
                ))
model.add(MaxPool2D(pool_size=(2,2))) # => 14*14*32
model.add(Dropout(0.1))
model.add(Conv2D(64, (3,3), activation='relu')) #=> ((14-3+1)*(14-3+1)*32 ) *64
model.add(MaxPool2D(pool_size=(2,2))) #=> 6*6
model.add(Dropout(0.25))
model.add(Flatten()) # 입력을 1차원으로 
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 315,146
# Trainable params: 315,146
# Non-trainable params: 0
# _________________________________________________________________

# %%
print('실제값:',y_test)
print('실제값:', Y_test.argmax(axis=1))

yhat = np.argmax(model.predict(X_test),axis=1)
print('예측값:',yhat)
# Out:
# 실제값: [7 2 1 ... 4 5 6]
# 실제값: [7 2 1 ... 4 5 6]
# 313/313 [==============================] - 2s 5ms/step
# 예측값: [1 1 1 ... 1 1 1]
