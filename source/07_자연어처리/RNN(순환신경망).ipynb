# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:20pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:20pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %% [markdown]
# **<font size="6" color="red">ch4.RNN(Recurrent Neural Network 순환신경망)</font>**
#
# # 1. 연관분석 개요

# %% [markdown]
# # 1. 문맥을 이용하여 모델만들기

# %%
text = """ 경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다 """
text1= "장마철이 오고 있다"

# %%
from keras_preprocessing.text import Tokenizer
t= Tokenizer()
t.fit_on_texts([text])
encoded = t.texts_to_sequences([text])
print(encoded)
print(t.word_index)
# Out:
# [[2, 3, 1, 4, 5, 6, 1, 7, 8, 1, 9, 10, 1, 11]]
# {'말이': 1, '경마장에': 2, '있는': 3, '뛰고': 4, '있다': 5, '그의': 6, '법이다': 7, '가는': 8, '고와야': 9, '오는': 10, '곱다': 11}

# %%
# 문자열 리스트를 인덱스 시퀀스로 변환
print(t.texts_to_sequences(['경마장에 말이 있다','말이 뛴다']))
print(t.texts_to_sequences(['가는 말이 곱다'])[0])
# Out:
# [[2, 1, 5], [1]]
# [8, 1, 11]

# %%
text = """경마장에 있는 말이 뛰고 있다
그의 말이 법이다
가는 말이 고와야 오는 말이 곱다"""

# %%
for key, value in t.word_index.items():
    print(key, value)
# Out:
# 말이 1
# 경마장에 2
# 있는 3
# 뛰고 4
# 있다 5
# 그의 6
# 법이다 7
# 가는 8
# 고와야 9
# 오는 10
# 곱다 11

# %%
# 학습을 시키기 위해 ['경마장에 있는','경마장에 있는 말이', ...]
sequences = []
for line in text.split('\n'):
    print('원문장 :', line)
    encoded = t.texts_to_sequences([line])[0]
    print('encoded된 문장 :', encoded)
    for i in range(0, len(encoded)-1): # i:시작index
        for j in range(i+2, len(encoded)+1): # j:끝나는 index바로 뒤
            sequences.append(encoded[i:j])
# print(sequences)
print('sequences와 해석 출력')
for sequence in sequences:
    for word_seq in sequence:
        for word, id in t.word_index.items():
            if word_seq==id:
                print("{}:{}".format(word_seq, word), end=' ')
                break
    print()
# Out:
# 원문장 : 경마장에 있는 말이 뛰고 있다
# encoded된 문장 : [2, 3, 1, 4, 5]
# 원문장 : 그의 말이 법이다
# encoded된 문장 : [6, 1, 7]
# 원문장 : 가는 말이 고와야 오는 말이 곱다
# encoded된 문장 : [8, 1, 9, 10, 1, 11]
# sequences와 해석 출력
# 2:경마장에 3:있는
# 2:경마장에 3:있는 1:말이
# 2:경마장에 3:있는 1:말이 4:뛰고
# 2:경마장에 3:있는 1:말이 4:뛰고 5:있다
# 3:있는 1:말이
# 3:있는 1:말이 4:뛰고
# 3:있는 1:말이 4:뛰고 5:있다
# 1:말이 4:뛰고
# 1:말이 4:뛰고 5:있다
# 4:뛰고 5:있다
# 6:그의 1:말이
# 6:그의 1:말이 7:법이다
# 1:말이 7:법이다
# 8:가는 1:말이
# 8:가는 1:말이 9:고와야
# 8:가는 1:말이 9:고와야 10:오는
# 8:가는 1:말이 9:고와야 10:오는 1:말이
# 8:가는 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 1:말이 9:고와야
# 1:말이 9:고와야 10:오는
# 1:말이 9:고와야 10:오는 1:말이
# 1:말이 9:고와야 10:오는 1:말이 11:곱다
# 9:고와야 10:오는
# 9:고와야 10:오는 1:말이
# 9:고와야 10:오는 1:말이 11:곱다
# 10:오는 1:말이
# 10:오는 1:말이 11:곱다
# 1:말이 11:곱다

# %%
# Out:
# [[2, 3],
#  [2, 3, 1],
#  [2, 3, 1, 4],
#  [2, 3, 1, 4, 5],
#  [3, 1],
#  [3, 1, 4],
#  [3, 1, 4, 5],
#  [1, 4],
#  [1, 4, 5],
#  [4, 5],
#  [6, 1],
#  [6, 1, 7],
#  [1, 7],
#  [8, 1],
#  [8, 1, 9],
#  [8, 1, 9, 10],
#  [8, 1, 9, 10, 1],
#  [8, 1, 9, 10, 1, 11],
#  [1, 9],
#  [1, 9, 10],
#  [1, 9, 10, 1],
#  [1, 9, 10, 1, 11],
#  [9, 10],
#  [9, 10, 1],
#  [9, 10, 1, 11],
#  [10, 1],
#  [10, 1, 11],
#  [1, 11]]

# %%
print([len(sequence) for sequence in sequences])
my_len = max(len(sequence) for sequence in sequences)
my_len
# Out:
# [2, 3, 4, 5, 2, 3, 4, 2, 3, 2, 2, 3, 2, 2, 3, 4, 5, 6, 2, 3, 4, 5, 2, 3, 4, 2, 3, 2]
# 6

# %%
# sequences를 훈련 가능하도록 모두 6개로 조정
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_sequences = pad_sequences(sequences=sequences,
                                maxlen=my_len,
                                padding = 'pre'
                                )
padded_sequences
padded_sequences.shape, type(padded_sequences)
# Out:
# ((28, 6), numpy.ndarray)

# %%
# 독립변수(X)와 타겟변수(y)로 분리
X = padded_sequences[:, :-1]
y = padded_sequences[:, -1]
y
# Out:
# array([ 3,  1,  4,  5,  1,  4,  5,  4,  5,  5,  1,  7,  7,  1,  9, 10,  1,
#        11,  9, 10,  1, 11, 10,  1, 11,  1, 11, 11])

# %%
# X를 엠베딩 작업할 때 필요한 입력 bit 수 (단어수+1) 
input_dim = len(t.word_index)+1
input_dim
# Out:
# 12

# %%
# y의 원핫인코딩
from tensorflow.keras.utils import to_categorical
Y = to_categorical(y, input_dim)
X.shape, Y.shape, input_dim
# Out:
# ((28, 5), (28, 12), 12)

# %%
# 2. 모델 생성하기
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding # Xi의 원핫인코딩한 희소행렬 변환
from tensorflow.keras.layers import SimpleRNN, Dense
import matplotlib.pyplot as plt

model= Sequential()
model.add(Embedding(input_dim= input_dim, # 12개로 원핫인코딩
                   output_dim=10, #임베딩출력의 개수
                   input_length=X.shape[1])) #입력(X)의 수
model.add(SimpleRNN(units=32))
model.add(Dense(12,activation='softmax'))
print(model.summary())

#3. 모델학습과정설정
model.compile(loss='categorical_crossentropy', 
              optimizer='adam',
             metrics=['accuracy'])
# 4. 모델 학습시키기
hist = model.fit(X, Y, epochs=300, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 5, 10)             120
#
#  simple_rnn (SimpleRNN)      (None, 32)                1376
#
#  dense (Dense)               (None, 12)                396
#
# =================================================================
# Total params: 1,892
# Trainable params: 1,892
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/300
# 1/1 - 1s - loss: 2.4786 - accuracy: 0.1071 - 1s/epoch - 1s/step
# Epoch 2/300
# 1/1 - 0s - loss: 2.4666 - accuracy: 0.1786 - 4ms/epoch - 4ms/step
# Epoch 3/300
# 1/1 - 0s - loss: 2.4547 - accuracy: 0.3214 - 3ms/epoch - 3ms/step
# Epoch 4/300
# 1/1 - 0s - loss: 2.4429 - accuracy: 0.3929 - 5ms/epoch - 5ms/step
# Epoch 5/300
# 1/1 - 0s - loss: 2.4311 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 6/300
# 1/1 - 0s - loss: 2.4191 - accuracy: 0.5357 - 6ms/epoch - 6ms/step
# Epoch 7/300
# 1/1 - 0s - loss: 2.4069 - accuracy: 0.4643 - 6ms/epoch - 6ms/step
# Epoch 8/300
# 1/1 - 0s - loss: 2.3944 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 9/300
# 1/1 - 0s - loss: 2.3815 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 10/300
# 1/1 - 0s - loss: 2.3682 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 11/300
# 1/1 - 0s - loss: 2.3543 - accuracy: 0.5714 - 6ms/epoch - 6ms/step
# Epoch 12/300
# 1/1 - 0s - loss: 2.3398 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 13/300
# 1/1 - 0s - loss: 2.3246 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 14/300
# 1/1 - 0s - loss: 2.3086 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 15/300
# 1/1 - 0s - loss: 2.2917 - accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 16/300
# 1/1 - 0s - loss: 2.2740 - accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 17/300
# 1/1 - 0s - loss: 2.2554 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 18/300
# 1/1 - 0s - loss: 2.2358 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 19/300
# 1/1 - 0s - loss: 2.2153 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 20/300
# 1/1 - 0s - loss: 2.1939 - accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 21/300
# 1/1 - 0s - loss: 2.1717 - accuracy: 0.4286 - 6ms/epoch - 6ms/step
# Epoch 22/300
# 1/1 - 0s - loss: 2.1487 - accuracy: 0.4286 - 6ms/epoch - 6ms/step
# Epoch 23/300
# 1/1 - 0s - loss: 2.1252 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 24/300
# 1/1 - 0s - loss: 2.1013 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 25/300
# 1/1 - 0s - loss: 2.0774 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 26/300
# 1/1 - 0s - loss: 2.0537 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 27/300
# 1/1 - 0s - loss: 2.0307 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 28/300
# 1/1 - 0s - loss: 2.0087 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 29/300
# 1/1 - 0s - loss: 1.9883 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 30/300
# 1/1 - 0s - loss: 1.9698 - accuracy: 0.3214 - 4ms/epoch - 4ms/step
# Epoch 31/300
# 1/1 - 0s - loss: 1.9536 - accuracy: 0.3214 - 11ms/epoch - 11ms/step
# Epoch 32/300
# 1/1 - 0s - loss: 1.9395 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 33/300
# 1/1 - 0s - loss: 1.9277 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 34/300
# 1/1 - 0s - loss: 1.9176 - accuracy: 0.2857 - 5ms/epoch - 5ms/step
# Epoch 35/300
# 1/1 - 0s - loss: 1.9087 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 36/300
# 1/1 - 0s - loss: 1.9004 - accuracy: 0.2857 - 4ms/epoch - 4ms/step
# Epoch 37/300
# 1/1 - 0s - loss: 1.8921 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 38/300
# 1/1 - 0s - loss: 1.8833 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 39/300
# 1/1 - 0s - loss: 1.8739 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 40/300
# 1/1 - 0s - loss: 1.8637 - accuracy: 0.3214 - 5ms/epoch - 5ms/step
# Epoch 41/300
# 1/1 - 0s - loss: 1.8528 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 42/300
# 1/1 - 0s - loss: 1.8415 - accuracy: 0.3214 - 6ms/epoch - 6ms/step
# Epoch 43/300
# 1/1 - 0s - loss: 1.8298 - accuracy: 0.3214 - 7ms/epoch - 7ms/step
# Epoch 44/300
# 1/1 - 0s - loss: 1.8181 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 45/300
# 1/1 - 0s - loss: 1.8065 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 46/300
# 1/1 - 0s - loss: 1.7951 - accuracy: 0.3571 - 6ms/epoch - 6ms/step
# Epoch 47/300
# 1/1 - 0s - loss: 1.7839 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 48/300
# 1/1 - 0s - loss: 1.7730 - accuracy: 0.3571 - 5ms/epoch - 5ms/step
# Epoch 49/300
# 1/1 - 0s - loss: 1.7623 - accuracy: 0.3929 - 6ms/epoch - 6ms/step
# Epoch 50/300
# 1/1 - 0s - loss: 1.7516 - accuracy: 0.3929 - 4ms/epoch - 4ms/step
# Epoch 51/300
# 1/1 - 0s - loss: 1.7410 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 52/300
# 1/1 - 0s - loss: 1.7302 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 53/300
# 1/1 - 0s - loss: 1.7193 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 54/300
# 1/1 - 0s - loss: 1.7081 - accuracy: 0.4286 - 3ms/epoch - 3ms/step
# Epoch 55/300
# 1/1 - 0s - loss: 1.6966 - accuracy: 0.4286 - 4ms/epoch - 4ms/step
# Epoch 56/300
# 1/1 - 0s - loss: 1.6848 - accuracy: 0.4286 - 5ms/epoch - 5ms/step
# Epoch 57/300
# 1/1 - 0s - loss: 1.6726 - accuracy: 0.4286 - 3ms/epoch - 3ms/step
# Epoch 58/300
# 1/1 - 0s - loss: 1.6602 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 59/300
# 1/1 - 0s - loss: 1.6475 - accuracy: 0.4643 - 3ms/epoch - 3ms/step
# Epoch 60/300
# 1/1 - 0s - loss: 1.6345 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 61/300
# 1/1 - 0s - loss: 1.6212 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 62/300
# 1/1 - 0s - loss: 1.6078 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 63/300
# 1/1 - 0s - loss: 1.5942 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 64/300
# 1/1 - 0s - loss: 1.5805 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 65/300
# 1/1 - 0s - loss: 1.5666 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 66/300
# 1/1 - 0s - loss: 1.5526 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 67/300
# 1/1 - 0s - loss: 1.5385 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 68/300
# 1/1 - 0s - loss: 1.5244 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 69/300
# 1/1 - 0s - loss: 1.5102 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 70/300
# 1/1 - 0s - loss: 1.4959 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 71/300
# 1/1 - 0s - loss: 1.4816 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 72/300
# 1/1 - 0s - loss: 1.4673 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 73/300
# 1/1 - 0s - loss: 1.4530 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 74/300
# 1/1 - 0s - loss: 1.4387 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 75/300
# 1/1 - 0s - loss: 1.4244 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 76/300
# 1/1 - 0s - loss: 1.4102 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 77/300
# 1/1 - 0s - loss: 1.3961 - accuracy: 0.5357 - 5ms/epoch - 5ms/step
# Epoch 78/300
# 1/1 - 0s - loss: 1.3820 - accuracy: 0.5357 - 3ms/epoch - 3ms/step
# Epoch 79/300
# 1/1 - 0s - loss: 1.3681 - accuracy: 0.5357 - 4ms/epoch - 4ms/step
# Epoch 80/300
# 1/1 - 0s - loss: 1.3542 - accuracy: 0.5714 - 12ms/epoch - 12ms/step
# Epoch 81/300
# 1/1 - 0s - loss: 1.3405 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 82/300
# 1/1 - 0s - loss: 1.3268 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 83/300
# 1/1 - 0s - loss: 1.3133 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 84/300
# 1/1 - 0s - loss: 1.3000 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 85/300
# 1/1 - 0s - loss: 1.2868 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 86/300
# 1/1 - 0s - loss: 1.2737 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 87/300
# 1/1 - 0s - loss: 1.2608 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 88/300
# 1/1 - 0s - loss: 1.2480 - accuracy: 0.5714 - 5ms/epoch - 5ms/step
# Epoch 89/300
# 1/1 - 0s - loss: 1.2354 - accuracy: 0.5714 - 3ms/epoch - 3ms/step
# Epoch 90/300
# 1/1 - 0s - loss: 1.2230 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 91/300
# 1/1 - 0s - loss: 1.2107 - accuracy: 0.5714 - 3ms/epoch - 3ms/step
# Epoch 92/300
# 1/1 - 0s - loss: 1.1986 - accuracy: 0.5714 - 4ms/epoch - 4ms/step
# Epoch 93/300
# 1/1 - 0s - loss: 1.1866 - accuracy: 0.6071 - 4ms/epoch - 4ms/step
# Epoch 94/300
# 1/1 - 0s - loss: 1.1748 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 95/300
# 1/1 - 0s - loss: 1.1632 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 96/300
# 1/1 - 0s - loss: 1.1517 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 97/300
# 1/1 - 0s - loss: 1.1403 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 98/300
# 1/1 - 0s - loss: 1.1291 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 99/300
# 1/1 - 0s - loss: 1.1180 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 100/300
# 1/1 - 0s - loss: 1.1071 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 101/300
# 1/1 - 0s - loss: 1.0963 - accuracy: 0.6429 - 4ms/epoch - 4ms/step
# Epoch 102/300
# 1/1 - 0s - loss: 1.0856 - accuracy: 0.6429 - 3ms/epoch - 3ms/step
# Epoch 103/300
# 1/1 - 0s - loss: 1.0751 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 104/300
# 1/1 - 0s - loss: 1.0647 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 105/300
# 1/1 - 0s - loss: 1.0545 - accuracy: 0.6786 - 4ms/epoch - 4ms/step
# Epoch 106/300
# 1/1 - 0s - loss: 1.0444 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 107/300
# 1/1 - 0s - loss: 1.0344 - accuracy: 0.6786 - 5ms/epoch - 5ms/step
# Epoch 108/300
# 1/1 - 0s - loss: 1.0245 - accuracy: 0.6786 - 3ms/epoch - 3ms/step
# Epoch 109/300
# 1/1 - 0s - loss: 1.0148 - accuracy: 0.6786 - 6ms/epoch - 6ms/step
# Epoch 110/300
# 1/1 - 0s - loss: 1.0052 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 111/300
# 1/1 - 0s - loss: 0.9957 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 112/300
# 1/1 - 0s - loss: 0.9864 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 113/300
# 1/1 - 0s - loss: 0.9771 - accuracy: 0.7143 - 5ms/epoch - 5ms/step
# Epoch 114/300
# 1/1 - 0s - loss: 0.9680 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 115/300
# 1/1 - 0s - loss: 0.9590 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 116/300
# 1/1 - 0s - loss: 0.9501 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 117/300
# 1/1 - 0s - loss: 0.9413 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 118/300
# 1/1 - 0s - loss: 0.9325 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 119/300
# 1/1 - 0s - loss: 0.9239 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 120/300
# 1/1 - 0s - loss: 0.9154 - accuracy: 0.7143 - 4ms/epoch - 4ms/step
# Epoch 121/300
# 1/1 - 0s - loss: 0.9070 - accuracy: 0.7143 - 3ms/epoch - 3ms/step
# Epoch 122/300
# 1/1 - 0s - loss: 0.8986 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 123/300
# 1/1 - 0s - loss: 0.8904 - accuracy: 0.7500 - 4ms/epoch - 4ms/step
# Epoch 124/300
# 1/1 - 0s - loss: 0.8822 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 125/300
# 1/1 - 0s - loss: 0.8741 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 126/300
# 1/1 - 0s - loss: 0.8661 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 127/300
# 1/1 - 0s - loss: 0.8582 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 128/300
# 1/1 - 0s - loss: 0.8504 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 129/300
# 1/1 - 0s - loss: 0.8426 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 130/300
# 1/1 - 0s - loss: 0.8349 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 131/300
# 1/1 - 0s - loss: 0.8273 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 132/300
# 1/1 - 0s - loss: 0.8198 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 133/300
# 1/1 - 0s - loss: 0.8123 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 134/300
# 1/1 - 0s - loss: 0.8049 - accuracy: 0.7857 - 5ms/epoch - 5ms/step
# Epoch 135/300
# 1/1 - 0s - loss: 0.7976 - accuracy: 0.7857 - 3ms/epoch - 3ms/step
# Epoch 136/300
# 1/1 - 0s - loss: 0.7904 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 137/300
# 1/1 - 0s - loss: 0.7832 - accuracy: 0.7857 - 4ms/epoch - 4ms/step
# Epoch 138/300
# 1/1 - 0s - loss: 0.7761 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 139/300
# 1/1 - 0s - loss: 0.7690 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 140/300
# 1/1 - 0s - loss: 0.7621 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 141/300
# 1/1 - 0s - loss: 0.7551 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 142/300
# 1/1 - 0s - loss: 0.7483 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 143/300
# 1/1 - 0s - loss: 0.7415 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 144/300
# 1/1 - 0s - loss: 0.7348 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 145/300
# 1/1 - 0s - loss: 0.7281 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 146/300
# 1/1 - 0s - loss: 0.7216 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 147/300
# 1/1 - 0s - loss: 0.7150 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 148/300
# 1/1 - 0s - loss: 0.7086 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 149/300
# 1/1 - 0s - loss: 0.7022 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 150/300
# 1/1 - 0s - loss: 0.6958 - accuracy: 0.8214 - 6ms/epoch - 6ms/step
# Epoch 151/300
# 1/1 - 0s - loss: 0.6896 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 152/300
# 1/1 - 0s - loss: 0.6834 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 153/300
# 1/1 - 0s - loss: 0.6772 - accuracy: 0.8214 - 4ms/epoch - 4ms/step
# Epoch 154/300
# 1/1 - 0s - loss: 0.6711 - accuracy: 0.8214 - 3ms/epoch - 3ms/step
# Epoch 155/300
# 1/1 - 0s - loss: 0.6651 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 156/300
# 1/1 - 0s - loss: 0.6591 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 157/300
# 1/1 - 0s - loss: 0.6533 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 158/300
# 1/1 - 0s - loss: 0.6474 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 159/300
# 1/1 - 0s - loss: 0.6417 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 160/300
# 1/1 - 0s - loss: 0.6359 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 161/300
# 1/1 - 0s - loss: 0.6303 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 162/300
# 1/1 - 0s - loss: 0.6247 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 163/300
# 1/1 - 0s - loss: 0.6192 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 164/300
# 1/1 - 0s - loss: 0.6138 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 165/300
# 1/1 - 0s - loss: 0.6084 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 166/300
# 1/1 - 0s - loss: 0.6030 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 167/300
# 1/1 - 0s - loss: 0.5978 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 168/300
# 1/1 - 0s - loss: 0.5926 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 169/300
# 1/1 - 0s - loss: 0.5874 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 170/300
# 1/1 - 0s - loss: 0.5824 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 171/300
# 1/1 - 0s - loss: 0.5773 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 172/300
# 1/1 - 0s - loss: 0.5724 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 173/300
# 1/1 - 0s - loss: 0.5675 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 174/300
# 1/1 - 0s - loss: 0.5627 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 175/300
# 1/1 - 0s - loss: 0.5579 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 176/300
# 1/1 - 0s - loss: 0.5532 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 177/300
# 1/1 - 0s - loss: 0.5485 - accuracy: 0.8571 - 11ms/epoch - 11ms/step
# Epoch 178/300
# 1/1 - 0s - loss: 0.5440 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 179/300
# 1/1 - 0s - loss: 0.5394 - accuracy: 0.8571 - 6ms/epoch - 6ms/step
# Epoch 180/300
# 1/1 - 0s - loss: 0.5350 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 181/300
# 1/1 - 0s - loss: 0.5306 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 182/300
# 1/1 - 0s - loss: 0.5262 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 183/300
# 1/1 - 0s - loss: 0.5219 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 184/300
# 1/1 - 0s - loss: 0.5177 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 185/300
# 1/1 - 0s - loss: 0.5135 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 186/300
# 1/1 - 0s - loss: 0.5094 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 187/300
# 1/1 - 0s - loss: 0.5053 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 188/300
# 1/1 - 0s - loss: 0.5013 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 189/300
# 1/1 - 0s - loss: 0.4973 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 190/300
# 1/1 - 0s - loss: 0.4934 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 191/300
# 1/1 - 0s - loss: 0.4896 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 192/300
# 1/1 - 0s - loss: 0.4858 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 193/300
# 1/1 - 0s - loss: 0.4820 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 194/300
# 1/1 - 0s - loss: 0.4783 - accuracy: 0.8571 - 3ms/epoch - 3ms/step
# Epoch 195/300
# 1/1 - 0s - loss: 0.4747 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 196/300
# 1/1 - 0s - loss: 0.4711 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 197/300
# 1/1 - 0s - loss: 0.4675 - accuracy: 0.8571 - 4ms/epoch - 4ms/step
# Epoch 198/300
# 1/1 - 0s - loss: 0.4640 - accuracy: 0.8571 - 5ms/epoch - 5ms/step
# Epoch 199/300
# 1/1 - 0s - loss: 0.4606 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 200/300
# 1/1 - 0s - loss: 0.4572 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 201/300
# 1/1 - 0s - loss: 0.4538 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 202/300
# 1/1 - 0s - loss: 0.4505 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 203/300
# 1/1 - 0s - loss: 0.4473 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 204/300
# 1/1 - 0s - loss: 0.4441 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 205/300
# 1/1 - 0s - loss: 0.4409 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 206/300
# 1/1 - 0s - loss: 0.4378 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 207/300
# 1/1 - 0s - loss: 0.4347 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 208/300
# 1/1 - 0s - loss: 0.4316 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 209/300
# 1/1 - 0s - loss: 0.4287 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 210/300
# 1/1 - 0s - loss: 0.4257 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 211/300
# 1/1 - 0s - loss: 0.4228 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 212/300
# 1/1 - 0s - loss: 0.4199 - accuracy: 0.8929 - 7ms/epoch - 7ms/step
# Epoch 213/300
# 1/1 - 0s - loss: 0.4171 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 214/300
# 1/1 - 0s - loss: 0.4143 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 215/300
# 1/1 - 0s - loss: 0.4116 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 216/300
# 1/1 - 0s - loss: 0.4089 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 217/300
# 1/1 - 0s - loss: 0.4062 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 218/300
# 1/1 - 0s - loss: 0.4036 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 219/300
# 1/1 - 0s - loss: 0.4010 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 220/300
# 1/1 - 0s - loss: 0.3984 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 221/300
# 1/1 - 0s - loss: 0.3959 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 222/300
# 1/1 - 0s - loss: 0.3934 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 223/300
# 1/1 - 0s - loss: 0.3910 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 224/300
# 1/1 - 0s - loss: 0.3886 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 225/300
# 1/1 - 0s - loss: 0.3862 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 226/300
# 1/1 - 0s - loss: 0.3838 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 227/300
# 1/1 - 0s - loss: 0.3815 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 228/300
# 1/1 - 0s - loss: 0.3793 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 229/300
# 1/1 - 0s - loss: 0.3770 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 230/300
# 1/1 - 0s - loss: 0.3748 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 231/300
# 1/1 - 0s - loss: 0.3726 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 232/300
# 1/1 - 0s - loss: 0.3705 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 233/300
# 1/1 - 0s - loss: 0.3684 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 234/300
# 1/1 - 0s - loss: 0.3663 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 235/300
# 1/1 - 0s - loss: 0.3642 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 236/300
# 1/1 - 0s - loss: 0.3622 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 237/300
# 1/1 - 0s - loss: 0.3602 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 238/300
# 1/1 - 0s - loss: 0.3582 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 239/300
# 1/1 - 0s - loss: 0.3563 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 240/300
# 1/1 - 0s - loss: 0.3544 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 241/300
# 1/1 - 0s - loss: 0.3525 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 242/300
# 1/1 - 0s - loss: 0.3507 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 243/300
# 1/1 - 0s - loss: 0.3488 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 244/300
# 1/1 - 0s - loss: 0.3470 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 245/300
# 1/1 - 0s - loss: 0.3453 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 246/300
# 1/1 - 0s - loss: 0.3435 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 247/300
# 1/1 - 0s - loss: 0.3418 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 248/300
# 1/1 - 0s - loss: 0.3401 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 249/300
# 1/1 - 0s - loss: 0.3384 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 250/300
# 1/1 - 0s - loss: 0.3368 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 251/300
# 1/1 - 0s - loss: 0.3352 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 252/300
# 1/1 - 0s - loss: 0.3336 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 253/300
# 1/1 - 0s - loss: 0.3320 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 254/300
# 1/1 - 0s - loss: 0.3304 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 255/300
# 1/1 - 0s - loss: 0.3289 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 256/300
# 1/1 - 0s - loss: 0.3274 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 257/300
# 1/1 - 0s - loss: 0.3259 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 258/300
# 1/1 - 0s - loss: 0.3244 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 259/300
# 1/1 - 0s - loss: 0.3230 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 260/300
# 1/1 - 0s - loss: 0.3215 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 261/300
# 1/1 - 0s - loss: 0.3201 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 262/300
# 1/1 - 0s - loss: 0.3187 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 263/300
# 1/1 - 0s - loss: 0.3174 - accuracy: 0.8929 - 6ms/epoch - 6ms/step
# Epoch 264/300
# 1/1 - 0s - loss: 0.3160 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 265/300
# 1/1 - 0s - loss: 0.3147 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 266/300
# 1/1 - 0s - loss: 0.3134 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 267/300
# 1/1 - 0s - loss: 0.3121 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 268/300
# 1/1 - 0s - loss: 0.3108 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 269/300
# 1/1 - 0s - loss: 0.3096 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 270/300
# 1/1 - 0s - loss: 0.3083 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 271/300
# 1/1 - 0s - loss: 0.3071 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 272/300
# 1/1 - 0s - loss: 0.3059 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 273/300
# 1/1 - 0s - loss: 0.3047 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 274/300
# 1/1 - 0s - loss: 0.3035 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 275/300
# 1/1 - 0s - loss: 0.3024 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 276/300
# 1/1 - 0s - loss: 0.3012 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 277/300
# 1/1 - 0s - loss: 0.3001 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 278/300
# 1/1 - 0s - loss: 0.2990 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 279/300
# 1/1 - 0s - loss: 0.2979 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 280/300
# 1/1 - 0s - loss: 0.2968 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 281/300
# 1/1 - 0s - loss: 0.2957 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 282/300
# 1/1 - 0s - loss: 0.2947 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 283/300
# 1/1 - 0s - loss: 0.2936 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 284/300
# 1/1 - 0s - loss: 0.2926 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 285/300
# 1/1 - 0s - loss: 0.2916 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 286/300
# 1/1 - 0s - loss: 0.2906 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 287/300
# 1/1 - 0s - loss: 0.2896 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 288/300
# 1/1 - 0s - loss: 0.2887 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 289/300
# 1/1 - 0s - loss: 0.2877 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 290/300
# 1/1 - 0s - loss: 0.2868 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 291/300
# 1/1 - 0s - loss: 0.2858 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 292/300
# 1/1 - 0s - loss: 0.2849 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 293/300
# 1/1 - 0s - loss: 0.2840 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 294/300
# 1/1 - 0s - loss: 0.2831 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 295/300
# 1/1 - 0s - loss: 0.2822 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 296/300
# 1/1 - 0s - loss: 0.2813 - accuracy: 0.8929 - 5ms/epoch - 5ms/step
# Epoch 297/300
# 1/1 - 0s - loss: 0.2805 - accuracy: 0.8929 - 4ms/epoch - 4ms/step
# Epoch 298/300
# 1/1 - 0s - loss: 0.2796 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 299/300
# 1/1 - 0s - loss: 0.2788 - accuracy: 0.8929 - 3ms/epoch - 3ms/step
# Epoch 300/300
# 1/1 - 0s - loss: 0.2780 - accuracy: 0.8929 - 3ms/epoch - 3ms/step

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %%
# 모델 사용하기 (경마장에 있는 말이 -> 뛰고)
input_word = input('입력단어 :')
encoded = t.texts_to_sequences([input_word])[0]
input_data = pad_sequences([encoded], maxlen=my_len-1, padding='pre')
print('입력데이터 :', input_data)
result = model.predict(input_data, verbose=0).argmax()
word = t.index_word[result]
print('예측된 단어 :', word)
# Out:
# 입력단어 :김준서
# 입력데이터 : [[0 0 0 0 0]]
# 예측된 단어 : 말이

# %%
t.texts_to_sequences(['없는 단어'])
# Out:
# [[]]

# %% [markdown]
# # 2. 다음문장 예측해보기

# %%
# '경마장에' 이후에 올 단어 3개예측 - > 경마장에 있는 말이 뛰고
def sentence_generation(current_word ,n):
#     print('입력된 단어 :',current_word)
    for i in range(1, n+1):
        encoded=t.texts_to_sequences([current_word])[0]
        input_data = pad_sequences([encoded],maxlen=my_len-1,padding='pre')
        result = model.predict(input_data, verbose=0).argmax()
        word = t.index_word[result]
        current_word = current_word + ' '+word
    return current_word 
sentence_generation('가는', 3)
# Out:
# '가는 말이 고와야 오는'
