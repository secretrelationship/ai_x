# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:100% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:22pt;}
div.text_cell_render.rendered_html{font-size:18pt;}
div.text_cell_render.rendered_html{font-size:15pt;}
div.output {font-size:18pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:18pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:18pt;padding:5px;}
table.dataframe{font-size:18px;}
</style>
"""))
# Out:
# <style>
# div.container{width:100% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:22pt;}
# div.text_cell_render.rendered_html{font-size:18pt;}
# div.text_cell_render.rendered_html{font-size:15pt;}
# div.output {font-size:18pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:18pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:18pt;padding:5px;}
# table.dataframe{font-size:18px;}
# </style>

# %%
# import
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
# 데이터 생성 및 전처리(라벨인코딩만 하고, 원핫인코딩X)

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %% [markdown]
# # 1. 기본적인 DNN(원핫인코딩X)

# %%
# 모델 설정
# model = Sequential()
# model.add(Input(4,))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model = Sequential([
    Input(4,),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax')
])
model.summary() # 250+1530+93 = 1873개 파라미터
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                250
#
#  dense_1 (Dense)             (None, 30)                1530
#
#  dense_2 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습설정
model.compile(loss='sparse_categorical_crossentropy', # 라벨인코딩만 되어 있는 경우
             optimizer='adam',
             metrics=['accuracy'])
# 학습
earlyStropping = EarlyStopping(patience=50) # monitor='val_loss' 기본값
hist = model.fit(train_X, train_y, epochs=1000,
                validation_split=0.2,
                callbacks=[earlyStropping])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 66ms/step - loss: 2.7640 - accuracy: 0.2963 - val_loss: 1.8998 - val_accuracy: 0.4815
# Epoch 2/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 1.9619 - accuracy: 0.2963 - val_loss: 1.5196 - val_accuracy: 0.1111
# Epoch 3/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 1.4591 - accuracy: 0.2315 - val_loss: 1.3151 - val_accuracy: 0.2222
# Epoch 4/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 1.1651 - accuracy: 0.3611 - val_loss: 1.1990 - val_accuracy: 0.2222
# Epoch 5/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0232 - accuracy: 0.3611 - val_loss: 1.1350 - val_accuracy: 0.2593
# Epoch 6/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9855 - accuracy: 0.5185 - val_loss: 1.1260 - val_accuracy: 0.2963
# Epoch 7/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9893 - accuracy: 0.3426 - val_loss: 1.0920 - val_accuracy: 0.3333
# Epoch 8/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9495 - accuracy: 0.3889 - val_loss: 1.0354 - val_accuracy: 0.3704
# Epoch 9/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8858 - accuracy: 0.6667 - val_loss: 0.9654 - val_accuracy: 0.2963
# Epoch 10/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.8384 - accuracy: 0.5278 - val_loss: 0.8928 - val_accuracy: 0.6667
# Epoch 11/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7893 - accuracy: 0.6852 - val_loss: 0.8189 - val_accuracy: 0.7037
# Epoch 12/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7550 - accuracy: 0.7222 - val_loss: 0.7528 - val_accuracy: 0.7778
# Epoch 13/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7228 - accuracy: 0.8241 - val_loss: 0.7142 - val_accuracy: 0.7778
# Epoch 14/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7000 - accuracy: 0.8148 - val_loss: 0.6852 - val_accuracy: 0.7407
# Epoch 15/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6776 - accuracy: 0.8148 - val_loss: 0.6628 - val_accuracy: 0.7407
# Epoch 16/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6543 - accuracy: 0.7963 - val_loss: 0.6412 - val_accuracy: 0.7037
# Epoch 17/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6347 - accuracy: 0.7037 - val_loss: 0.6205 - val_accuracy: 0.7037
# Epoch 18/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6146 - accuracy: 0.7407 - val_loss: 0.5937 - val_accuracy: 0.7778
# Epoch 19/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5938 - accuracy: 0.8333 - val_loss: 0.5672 - val_accuracy: 0.8148
# Epoch 20/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5747 - accuracy: 0.8519 - val_loss: 0.5437 - val_accuracy: 0.8889
# Epoch 21/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5592 - accuracy: 0.8981 - val_loss: 0.5204 - val_accuracy: 0.9259
# Epoch 22/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5441 - accuracy: 0.9259 - val_loss: 0.5063 - val_accuracy: 0.8889
# Epoch 23/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5290 - accuracy: 0.9167 - val_loss: 0.4931 - val_accuracy: 0.8889
# Epoch 24/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5132 - accuracy: 0.9167 - val_loss: 0.4783 - val_accuracy: 0.8889
# Epoch 25/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4992 - accuracy: 0.8981 - val_loss: 0.4644 - val_accuracy: 0.8889
# Epoch 26/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4864 - accuracy: 0.8981 - val_loss: 0.4496 - val_accuracy: 0.8889
# Epoch 27/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4746 - accuracy: 0.8981 - val_loss: 0.4348 - val_accuracy: 0.8889
# Epoch 28/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4630 - accuracy: 0.8981 - val_loss: 0.4228 - val_accuracy: 0.8889
# Epoch 29/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4528 - accuracy: 0.9259 - val_loss: 0.4081 - val_accuracy: 0.8889
# Epoch 30/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4414 - accuracy: 0.9259 - val_loss: 0.3992 - val_accuracy: 0.8889
# Epoch 31/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4316 - accuracy: 0.9259 - val_loss: 0.3894 - val_accuracy: 0.8889
# Epoch 32/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4224 - accuracy: 0.9167 - val_loss: 0.3763 - val_accuracy: 0.8889
# Epoch 33/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4132 - accuracy: 0.9444 - val_loss: 0.3658 - val_accuracy: 0.9630
# Epoch 34/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4050 - accuracy: 0.9537 - val_loss: 0.3593 - val_accuracy: 0.9630
# Epoch 35/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3966 - accuracy: 0.9537 - val_loss: 0.3498 - val_accuracy: 0.9630
# Epoch 36/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.3886 - accuracy: 0.9722 - val_loss: 0.3438 - val_accuracy: 0.9630
# Epoch 37/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3799 - accuracy: 0.9630 - val_loss: 0.3416 - val_accuracy: 0.9630
# Epoch 38/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3728 - accuracy: 0.9352 - val_loss: 0.3389 - val_accuracy: 0.8889
# Epoch 39/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3659 - accuracy: 0.9352 - val_loss: 0.3264 - val_accuracy: 0.9630
# Epoch 40/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3592 - accuracy: 0.9444 - val_loss: 0.3193 - val_accuracy: 0.9630
# Epoch 41/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3516 - accuracy: 0.9722 - val_loss: 0.3108 - val_accuracy: 0.9630
# Epoch 42/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3450 - accuracy: 0.9722 - val_loss: 0.3099 - val_accuracy: 0.9630
# Epoch 43/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3386 - accuracy: 0.9444 - val_loss: 0.3077 - val_accuracy: 0.9630
# Epoch 44/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3324 - accuracy: 0.9444 - val_loss: 0.3030 - val_accuracy: 0.9259
# Epoch 45/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3261 - accuracy: 0.9537 - val_loss: 0.2927 - val_accuracy: 0.9630
# Epoch 46/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3190 - accuracy: 0.9722 - val_loss: 0.2822 - val_accuracy: 0.9630
# Epoch 47/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3145 - accuracy: 0.9722 - val_loss: 0.2744 - val_accuracy: 0.9630
# Epoch 48/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3103 - accuracy: 0.9815 - val_loss: 0.2726 - val_accuracy: 0.9630
# Epoch 49/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3034 - accuracy: 0.9630 - val_loss: 0.2816 - val_accuracy: 0.9630
# Epoch 50/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2988 - accuracy: 0.9352 - val_loss: 0.2771 - val_accuracy: 0.9630
# Epoch 51/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2931 - accuracy: 0.9352 - val_loss: 0.2648 - val_accuracy: 0.9630
# Epoch 52/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2852 - accuracy: 0.9630 - val_loss: 0.2571 - val_accuracy: 0.9630
# Epoch 53/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2861 - accuracy: 0.9722 - val_loss: 0.2432 - val_accuracy: 0.9630
# Epoch 54/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2748 - accuracy: 0.9722 - val_loss: 0.2474 - val_accuracy: 0.9630
# Epoch 55/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2681 - accuracy: 0.9722 - val_loss: 0.2409 - val_accuracy: 0.9630
# Epoch 56/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2625 - accuracy: 0.9722 - val_loss: 0.2278 - val_accuracy: 0.9630
# Epoch 57/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2583 - accuracy: 0.9815 - val_loss: 0.2244 - val_accuracy: 0.9630
# Epoch 58/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2527 - accuracy: 0.9722 - val_loss: 0.2307 - val_accuracy: 0.9630
# Epoch 59/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2470 - accuracy: 0.9722 - val_loss: 0.2252 - val_accuracy: 0.9630
# Epoch 60/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2417 - accuracy: 0.9722 - val_loss: 0.2200 - val_accuracy: 0.9630
# Epoch 61/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2370 - accuracy: 0.9722 - val_loss: 0.2112 - val_accuracy: 0.9630
# Epoch 62/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2322 - accuracy: 0.9815 - val_loss: 0.2090 - val_accuracy: 0.9630
# Epoch 63/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2281 - accuracy: 0.9815 - val_loss: 0.2030 - val_accuracy: 0.9630
# Epoch 64/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2204 - accuracy: 0.9722 - val_loss: 0.2049 - val_accuracy: 0.9630
# Epoch 65/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2172 - accuracy: 0.9722 - val_loss: 0.2039 - val_accuracy: 0.9630
# Epoch 66/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2150 - accuracy: 0.9630 - val_loss: 0.2015 - val_accuracy: 0.9630
# Epoch 67/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2103 - accuracy: 0.9722 - val_loss: 0.1865 - val_accuracy: 0.9630
# Epoch 68/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2065 - accuracy: 0.9815 - val_loss: 0.1815 - val_accuracy: 0.9630
# Epoch 69/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2042 - accuracy: 0.9815 - val_loss: 0.1829 - val_accuracy: 0.9630
# Epoch 70/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1964 - accuracy: 0.9815 - val_loss: 0.1864 - val_accuracy: 0.9630
# Epoch 71/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1940 - accuracy: 0.9722 - val_loss: 0.1809 - val_accuracy: 0.9630
# Epoch 72/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1937 - accuracy: 0.9722 - val_loss: 0.1717 - val_accuracy: 0.9630
# Epoch 73/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1877 - accuracy: 0.9815 - val_loss: 0.1697 - val_accuracy: 0.9630
# Epoch 74/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1830 - accuracy: 0.9815 - val_loss: 0.1666 - val_accuracy: 0.9630
# Epoch 75/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1797 - accuracy: 0.9815 - val_loss: 0.1638 - val_accuracy: 0.9630
# Epoch 76/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1766 - accuracy: 0.9815 - val_loss: 0.1614 - val_accuracy: 0.9630
# Epoch 77/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1737 - accuracy: 0.9815 - val_loss: 0.1606 - val_accuracy: 0.9630
# Epoch 78/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1686 - accuracy: 0.9815 - val_loss: 0.1679 - val_accuracy: 0.9630
# Epoch 79/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1700 - accuracy: 0.9722 - val_loss: 0.1666 - val_accuracy: 0.9630
# Epoch 80/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1672 - accuracy: 0.9722 - val_loss: 0.1554 - val_accuracy: 0.9630
# Epoch 81/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1608 - accuracy: 0.9815 - val_loss: 0.1489 - val_accuracy: 0.9630
# Epoch 82/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1590 - accuracy: 0.9815 - val_loss: 0.1456 - val_accuracy: 0.9630
# Epoch 83/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1625 - accuracy: 0.9815 - val_loss: 0.1413 - val_accuracy: 0.9259
# Epoch 84/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1556 - accuracy: 0.9815 - val_loss: 0.1473 - val_accuracy: 0.9630
# Epoch 85/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1520 - accuracy: 0.9815 - val_loss: 0.1495 - val_accuracy: 0.9630
# Epoch 86/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1532 - accuracy: 0.9722 - val_loss: 0.1487 - val_accuracy: 0.9630
# Epoch 87/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1486 - accuracy: 0.9722 - val_loss: 0.1393 - val_accuracy: 0.9630
# Epoch 88/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1445 - accuracy: 0.9815 - val_loss: 0.1331 - val_accuracy: 0.9630
# Epoch 89/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1458 - accuracy: 0.9907 - val_loss: 0.1318 - val_accuracy: 0.9630
# Epoch 90/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1420 - accuracy: 0.9815 - val_loss: 0.1318 - val_accuracy: 0.9630
# Epoch 91/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1388 - accuracy: 0.9815 - val_loss: 0.1310 - val_accuracy: 0.9630
# Epoch 92/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1371 - accuracy: 0.9815 - val_loss: 0.1302 - val_accuracy: 0.9630
# Epoch 93/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1348 - accuracy: 0.9815 - val_loss: 0.1317 - val_accuracy: 0.9630
# Epoch 94/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1364 - accuracy: 0.9815 - val_loss: 0.1359 - val_accuracy: 0.9630
# Epoch 95/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1346 - accuracy: 0.9815 - val_loss: 0.1233 - val_accuracy: 0.9630
# Epoch 96/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1314 - accuracy: 0.9907 - val_loss: 0.1219 - val_accuracy: 0.9630
# Epoch 97/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1292 - accuracy: 0.9815 - val_loss: 0.1222 - val_accuracy: 0.9630
# Epoch 98/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1266 - accuracy: 0.9815 - val_loss: 0.1231 - val_accuracy: 0.9630
# Epoch 99/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1276 - accuracy: 0.9815 - val_loss: 0.1240 - val_accuracy: 0.9630
# Epoch 100/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1225 - accuracy: 0.9815 - val_loss: 0.1168 - val_accuracy: 0.9630
# Epoch 101/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1268 - accuracy: 0.9907 - val_loss: 0.1168 - val_accuracy: 0.9630
# Epoch 102/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1260 - accuracy: 0.9815 - val_loss: 0.1368 - val_accuracy: 0.9630
# Epoch 103/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1287 - accuracy: 0.9630 - val_loss: 0.1280 - val_accuracy: 0.9630
# Epoch 104/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1217 - accuracy: 0.9815 - val_loss: 0.1133 - val_accuracy: 0.9630
# Epoch 105/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1209 - accuracy: 0.9907 - val_loss: 0.1117 - val_accuracy: 0.9259
# Epoch 106/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1172 - accuracy: 0.9907 - val_loss: 0.1146 - val_accuracy: 0.9630
# Epoch 107/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1162 - accuracy: 0.9815 - val_loss: 0.1292 - val_accuracy: 0.9630
# Epoch 108/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1204 - accuracy: 0.9722 - val_loss: 0.1214 - val_accuracy: 0.9630
# Epoch 109/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1134 - accuracy: 0.9815 - val_loss: 0.1086 - val_accuracy: 0.9630
# Epoch 110/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1134 - accuracy: 0.9907 - val_loss: 0.1078 - val_accuracy: 0.9259
# Epoch 111/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1127 - accuracy: 0.9815 - val_loss: 0.1120 - val_accuracy: 0.9630
# Epoch 112/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1089 - accuracy: 0.9815 - val_loss: 0.1103 - val_accuracy: 0.9630
# Epoch 113/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1083 - accuracy: 0.9907 - val_loss: 0.1069 - val_accuracy: 0.9630
# Epoch 114/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1072 - accuracy: 0.9907 - val_loss: 0.1070 - val_accuracy: 0.9630
# Epoch 115/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1055 - accuracy: 0.9815 - val_loss: 0.1065 - val_accuracy: 0.9630
# Epoch 116/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1046 - accuracy: 0.9815 - val_loss: 0.1057 - val_accuracy: 0.9630
# Epoch 117/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1047 - accuracy: 0.9907 - val_loss: 0.1036 - val_accuracy: 0.9630
# Epoch 118/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1029 - accuracy: 0.9907 - val_loss: 0.1080 - val_accuracy: 0.9630
# Epoch 119/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1046 - accuracy: 0.9815 - val_loss: 0.1108 - val_accuracy: 0.9630
# Epoch 120/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1026 - accuracy: 0.9815 - val_loss: 0.1030 - val_accuracy: 0.9630
# Epoch 121/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1019 - accuracy: 0.9907 - val_loss: 0.1018 - val_accuracy: 0.9630
# Epoch 122/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0980 - accuracy: 0.9815 - val_loss: 0.1118 - val_accuracy: 0.9630
# Epoch 123/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1052 - accuracy: 0.9815 - val_loss: 0.1135 - val_accuracy: 0.9630
# Epoch 124/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1013 - accuracy: 0.9815 - val_loss: 0.1000 - val_accuracy: 0.9630
# Epoch 125/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0996 - accuracy: 0.9907 - val_loss: 0.0973 - val_accuracy: 0.9259
# Epoch 126/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0985 - accuracy: 0.9907 - val_loss: 0.0980 - val_accuracy: 0.9630
# Epoch 127/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0961 - accuracy: 0.9815 - val_loss: 0.1051 - val_accuracy: 0.9630
# Epoch 128/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1001 - accuracy: 0.9815 - val_loss: 0.1049 - val_accuracy: 0.9630
# Epoch 129/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1001 - accuracy: 0.9815 - val_loss: 0.0955 - val_accuracy: 0.9259
# Epoch 130/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0962 - accuracy: 0.9907 - val_loss: 0.0953 - val_accuracy: 0.9259
# Epoch 131/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0940 - accuracy: 0.9907 - val_loss: 0.1000 - val_accuracy: 0.9630
# Epoch 132/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0925 - accuracy: 0.9815 - val_loss: 0.1012 - val_accuracy: 0.9630
# Epoch 133/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0939 - accuracy: 0.9815 - val_loss: 0.0976 - val_accuracy: 0.9630
# Epoch 134/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0914 - accuracy: 0.9815 - val_loss: 0.0981 - val_accuracy: 0.9630
# Epoch 135/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0911 - accuracy: 0.9907 - val_loss: 0.0945 - val_accuracy: 0.9630
# Epoch 136/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0903 - accuracy: 0.9907 - val_loss: 0.0938 - val_accuracy: 0.9630
# Epoch 137/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0903 - accuracy: 0.9907 - val_loss: 0.0987 - val_accuracy: 0.9630
# Epoch 138/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0906 - accuracy: 0.9815 - val_loss: 0.0986 - val_accuracy: 0.9630
# Epoch 139/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0899 - accuracy: 0.9815 - val_loss: 0.0946 - val_accuracy: 0.9630
# Epoch 140/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0930 - accuracy: 0.9907 - val_loss: 0.0911 - val_accuracy: 0.9259
# Epoch 141/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0876 - accuracy: 0.9907 - val_loss: 0.0948 - val_accuracy: 0.9630
# Epoch 142/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0883 - accuracy: 0.9815 - val_loss: 0.0965 - val_accuracy: 0.9630
# Epoch 143/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0879 - accuracy: 0.9907 - val_loss: 0.0910 - val_accuracy: 0.9630
# Epoch 144/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0861 - accuracy: 0.9907 - val_loss: 0.0900 - val_accuracy: 0.9630
# Epoch 145/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0869 - accuracy: 0.9907 - val_loss: 0.0899 - val_accuracy: 0.9630
# Epoch 146/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0869 - accuracy: 0.9907 - val_loss: 0.0893 - val_accuracy: 0.9259
# Epoch 147/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0877 - accuracy: 0.9907 - val_loss: 0.0892 - val_accuracy: 0.9259
# Epoch 148/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0868 - accuracy: 0.9815 - val_loss: 0.0976 - val_accuracy: 0.9630
# Epoch 149/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0881 - accuracy: 0.9815 - val_loss: 0.0947 - val_accuracy: 0.9630
# Epoch 150/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0857 - accuracy: 0.9907 - val_loss: 0.0893 - val_accuracy: 0.9630
# Epoch 151/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0844 - accuracy: 0.9907 - val_loss: 0.0916 - val_accuracy: 0.9630
# Epoch 152/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0821 - accuracy: 0.9907 - val_loss: 0.0881 - val_accuracy: 0.9630
# Epoch 153/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0830 - accuracy: 0.9907 - val_loss: 0.0885 - val_accuracy: 0.9630
# Epoch 154/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0806 - accuracy: 0.9815 - val_loss: 0.0968 - val_accuracy: 0.9630
# Epoch 155/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0847 - accuracy: 0.9815 - val_loss: 0.0937 - val_accuracy: 0.9630
# Epoch 156/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0799 - accuracy: 0.9907 - val_loss: 0.0874 - val_accuracy: 0.9630
# Epoch 157/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0813 - accuracy: 0.9907 - val_loss: 0.0867 - val_accuracy: 0.9259
# Epoch 158/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0826 - accuracy: 0.9907 - val_loss: 0.0892 - val_accuracy: 0.9630
# Epoch 159/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0790 - accuracy: 0.9907 - val_loss: 0.0916 - val_accuracy: 0.9630
# Epoch 160/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0793 - accuracy: 0.9815 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 161/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0810 - accuracy: 0.9907 - val_loss: 0.0858 - val_accuracy: 0.9259
# Epoch 162/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0785 - accuracy: 0.9907 - val_loss: 0.0869 - val_accuracy: 0.9630
# Epoch 163/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0776 - accuracy: 0.9907 - val_loss: 0.0885 - val_accuracy: 0.9630
# Epoch 164/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0773 - accuracy: 0.9907 - val_loss: 0.0870 - val_accuracy: 0.9630
# Epoch 165/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0766 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9630
# Epoch 166/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0805 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 167/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0748 - accuracy: 0.9907 - val_loss: 0.0897 - val_accuracy: 0.9630
# Epoch 168/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0797 - accuracy: 0.9815 - val_loss: 0.0969 - val_accuracy: 0.9630
# Epoch 169/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0798 - accuracy: 0.9815 - val_loss: 0.0877 - val_accuracy: 0.9630
# Epoch 170/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0746 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 171/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0818 - accuracy: 0.9815 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 172/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0749 - accuracy: 0.9907 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 173/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0770 - accuracy: 0.9815 - val_loss: 0.0932 - val_accuracy: 0.9630
# Epoch 174/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0759 - accuracy: 0.9815 - val_loss: 0.0850 - val_accuracy: 0.9630
# Epoch 175/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0728 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 176/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0769 - accuracy: 0.9907 - val_loss: 0.0833 - val_accuracy: 0.9259
# Epoch 177/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0754 - accuracy: 0.9907 - val_loss: 0.0832 - val_accuracy: 0.9259
# Epoch 178/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0747 - accuracy: 0.9907 - val_loss: 0.0885 - val_accuracy: 0.9630
# Epoch 179/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0754 - accuracy: 0.9815 - val_loss: 0.0912 - val_accuracy: 0.9630
# Epoch 180/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0749 - accuracy: 0.9815 - val_loss: 0.0834 - val_accuracy: 0.9630
# Epoch 181/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0750 - accuracy: 0.9907 - val_loss: 0.0824 - val_accuracy: 0.9259
# Epoch 182/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0739 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9630
# Epoch 183/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0712 - accuracy: 0.9907 - val_loss: 0.0860 - val_accuracy: 0.9630
# Epoch 184/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0738 - accuracy: 0.9815 - val_loss: 0.0863 - val_accuracy: 0.9630
# Epoch 185/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0727 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9630
# Epoch 186/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0704 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9630
# Epoch 187/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0722 - accuracy: 0.9907 - val_loss: 0.0868 - val_accuracy: 0.9630
# Epoch 188/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0727 - accuracy: 0.9815 - val_loss: 0.0861 - val_accuracy: 0.9630
# Epoch 189/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0701 - accuracy: 0.9907 - val_loss: 0.0825 - val_accuracy: 0.9630
# Epoch 190/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0707 - accuracy: 0.9907 - val_loss: 0.0817 - val_accuracy: 0.9259
# Epoch 191/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0716 - accuracy: 0.9907 - val_loss: 0.0819 - val_accuracy: 0.9259
# Epoch 192/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0698 - accuracy: 0.9907 - val_loss: 0.0816 - val_accuracy: 0.9259
# Epoch 193/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0724 - accuracy: 0.9907 - val_loss: 0.0821 - val_accuracy: 0.9630
# Epoch 194/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0680 - accuracy: 0.9907 - val_loss: 0.0861 - val_accuracy: 0.9630
# Epoch 195/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0712 - accuracy: 0.9815 - val_loss: 0.0863 - val_accuracy: 0.9630
# Epoch 196/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0725 - accuracy: 0.9907 - val_loss: 0.0812 - val_accuracy: 0.9259
# Epoch 197/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0697 - accuracy: 0.9907 - val_loss: 0.0818 - val_accuracy: 0.9630
# Epoch 198/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0675 - accuracy: 0.9907 - val_loss: 0.0856 - val_accuracy: 0.9630
# Epoch 199/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0718 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9630
# Epoch 200/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0686 - accuracy: 0.9907 - val_loss: 0.0867 - val_accuracy: 0.9630
# Epoch 201/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0706 - accuracy: 0.9815 - val_loss: 0.0844 - val_accuracy: 0.9630
# Epoch 202/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0680 - accuracy: 0.9907 - val_loss: 0.0811 - val_accuracy: 0.9259
# Epoch 203/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0700 - accuracy: 0.9907 - val_loss: 0.0820 - val_accuracy: 0.9259
# Epoch 204/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0894 - accuracy: 0.9815 - val_loss: 0.0822 - val_accuracy: 0.9259
# Epoch 205/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0761 - accuracy: 0.9907 - val_loss: 0.0990 - val_accuracy: 0.9630
# Epoch 206/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0833 - accuracy: 0.9722 - val_loss: 0.0978 - val_accuracy: 0.9630
# Epoch 207/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0725 - accuracy: 0.9815 - val_loss: 0.0806 - val_accuracy: 0.9259
# Epoch 208/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0758 - accuracy: 0.9815 - val_loss: 0.0840 - val_accuracy: 0.9259
# Epoch 209/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0763 - accuracy: 0.9815 - val_loss: 0.0837 - val_accuracy: 0.9630
# Epoch 210/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0670 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9630
# Epoch 211/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0659 - accuracy: 0.9907 - val_loss: 0.0805 - val_accuracy: 0.9259
# Epoch 212/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0671 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9259
# Epoch 213/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0667 - accuracy: 0.9907 - val_loss: 0.0812 - val_accuracy: 0.9630
# Epoch 214/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0654 - accuracy: 0.9907 - val_loss: 0.0833 - val_accuracy: 0.9630
# Epoch 215/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0683 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9630
# Epoch 216/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0666 - accuracy: 0.9907 - val_loss: 0.0808 - val_accuracy: 0.9630
# Epoch 217/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0657 - accuracy: 0.9907 - val_loss: 0.0829 - val_accuracy: 0.9630
# Epoch 218/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0649 - accuracy: 0.9907 - val_loss: 0.0816 - val_accuracy: 0.9630
# Epoch 219/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0734 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9259
# Epoch 220/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0644 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9630
# Epoch 221/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0655 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9630
# Epoch 222/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0685 - accuracy: 0.9907 - val_loss: 0.0807 - val_accuracy: 0.9259
# Epoch 223/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0650 - accuracy: 0.9907 - val_loss: 0.0819 - val_accuracy: 0.9630
# Epoch 224/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0637 - accuracy: 0.9907 - val_loss: 0.0822 - val_accuracy: 0.9630
# Epoch 225/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0642 - accuracy: 0.9907 - val_loss: 0.0828 - val_accuracy: 0.9630
# Epoch 226/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 0.9907 - val_loss: 0.0807 - val_accuracy: 0.9259
# Epoch 227/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0631 - accuracy: 0.9907 - val_loss: 0.0802 - val_accuracy: 0.9259
# Epoch 228/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0629 - accuracy: 0.9907 - val_loss: 0.0808 - val_accuracy: 0.9630
# Epoch 229/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0628 - accuracy: 0.9907 - val_loss: 0.0819 - val_accuracy: 0.9630
# Epoch 230/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0645 - accuracy: 0.9907 - val_loss: 0.0806 - val_accuracy: 0.9630
# Epoch 231/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0631 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9630
# Epoch 232/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0637 - accuracy: 0.9907 - val_loss: 0.0808 - val_accuracy: 0.9630
# Epoch 233/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0618 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 234/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9907 - val_loss: 0.0799 - val_accuracy: 0.9259
# Epoch 235/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0671 - accuracy: 0.9907 - val_loss: 0.0798 - val_accuracy: 0.9259
# Epoch 236/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 237/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0649 - accuracy: 0.9907 - val_loss: 0.0801 - val_accuracy: 0.9259
# Epoch 238/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0630 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9259
# Epoch 239/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0653 - accuracy: 0.9815 - val_loss: 0.0792 - val_accuracy: 0.9259
# Epoch 240/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0593 - accuracy: 0.9907 - val_loss: 0.0840 - val_accuracy: 0.9630
# Epoch 241/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0657 - accuracy: 0.9815 - val_loss: 0.0916 - val_accuracy: 0.9630
# Epoch 242/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0680 - accuracy: 0.9815 - val_loss: 0.0832 - val_accuracy: 0.9630
# Epoch 243/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0617 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9259
# Epoch 244/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0620 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9259
# Epoch 245/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0795 - val_accuracy: 0.9259
# Epoch 246/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0614 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9630
# Epoch 247/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0634 - accuracy: 0.9907 - val_loss: 0.0840 - val_accuracy: 0.9630
# Epoch 248/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9907 - val_loss: 0.0796 - val_accuracy: 0.9259
# Epoch 249/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0674 - accuracy: 0.9907 - val_loss: 0.0811 - val_accuracy: 0.9259
# Epoch 250/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0626 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9259
# Epoch 251/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0624 - accuracy: 0.9907 - val_loss: 0.0875 - val_accuracy: 0.9630
# Epoch 252/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0644 - accuracy: 0.9907 - val_loss: 0.0844 - val_accuracy: 0.9630
# Epoch 253/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0608 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 254/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0608 - accuracy: 0.9907 - val_loss: 0.0793 - val_accuracy: 0.9259
# Epoch 255/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0606 - accuracy: 0.9907 - val_loss: 0.0793 - val_accuracy: 0.9259
# Epoch 256/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0604 - accuracy: 0.9907 - val_loss: 0.0796 - val_accuracy: 0.9259
# Epoch 257/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0628 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9630
# Epoch 258/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0603 - accuracy: 0.9907 - val_loss: 0.0808 - val_accuracy: 0.9630
# Epoch 259/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0598 - accuracy: 0.9907 - val_loss: 0.0795 - val_accuracy: 0.9259
# Epoch 260/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0612 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 261/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 262/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0608 - accuracy: 0.9907 - val_loss: 0.0794 - val_accuracy: 0.9259
# Epoch 263/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9907 - val_loss: 0.0807 - val_accuracy: 0.9630
# Epoch 264/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0793 - val_accuracy: 0.9259
# Epoch 265/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9259
# Epoch 266/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0626 - accuracy: 0.9815 - val_loss: 0.0815 - val_accuracy: 0.9259
# Epoch 267/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9815 - val_loss: 0.0798 - val_accuracy: 0.9259
# Epoch 268/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0578 - accuracy: 0.9907 - val_loss: 0.0997 - val_accuracy: 0.9630
# Epoch 269/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0726 - accuracy: 0.9815 - val_loss: 0.0959 - val_accuracy: 0.9630
# Epoch 270/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0655 - accuracy: 0.9815 - val_loss: 0.0809 - val_accuracy: 0.9259
# Epoch 271/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0609 - accuracy: 0.9907 - val_loss: 0.0814 - val_accuracy: 0.9259
# Epoch 272/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0618 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9259
# Epoch 273/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0588 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9630
# Epoch 274/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0599 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9630
# Epoch 275/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0591 - accuracy: 0.9907 - val_loss: 0.0802 - val_accuracy: 0.9259
# Epoch 276/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0615 - accuracy: 0.9815 - val_loss: 0.0796 - val_accuracy: 0.9259
# Epoch 277/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0592 - accuracy: 0.9907 - val_loss: 0.0870 - val_accuracy: 0.9630
# Epoch 278/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0612 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9630
# Epoch 279/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0612 - accuracy: 0.9907 - val_loss: 0.0796 - val_accuracy: 0.9259
# Epoch 280/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0583 - accuracy: 0.9907 - val_loss: 0.0797 - val_accuracy: 0.9259
# Epoch 281/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0660 - accuracy: 0.9815 - val_loss: 0.0806 - val_accuracy: 0.9259
# Epoch 282/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0580 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9630
# Epoch 283/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0614 - accuracy: 0.9907 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 284/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0613 - accuracy: 0.9907 - val_loss: 0.0827 - val_accuracy: 0.9630
# Epoch 285/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0582 - accuracy: 0.9907 - val_loss: 0.0800 - val_accuracy: 0.9259
# Epoch 286/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0590 - accuracy: 0.9815 - val_loss: 0.0797 - val_accuracy: 0.9259
# Epoch 287/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0588 - accuracy: 0.9907 - val_loss: 0.0826 - val_accuracy: 0.9630
# Epoch 288/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0830 - val_accuracy: 0.9630
# Epoch 289/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0591 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9259

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend(loc='upper left')
plt.show()

# %% [markdown]
# # 2. sklearn 이용
# - 원핫인코딩을 하지 않고 라벨인코딩까지만 해야 작동, numpy 배열

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 머신러닝 3장 교안 43page
mlp_model = MLPClassifier(hidden_layer_sizes=(50,30),
                     activation='relu', 
                     solver='adam',
                     alpha=0.0001, # 과적합 방지 강도
                     batch_size=40,
                     max_iter=1000, # epoch
                     early_stopping=True, # 조기 종료 활성화(val_loss)
                     n_iter_no_change=50, # patience
                     warm_start=False, # True일 경우 이전학습에 이어서 학습 
                     validation_fraction=0.1) # 검증셋 비율

# %%
mlp_model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True, hidden_layer_sizes=(50, 30),
#               max_iter=1000, n_iter_no_change=50)

# %%
# 모델 평가 : accuracy(test_X,test_y), recall, precision(test_y, yhat)
from sklearn.metrics import recall_score, precision_score
accuracy = mlp_model.score(test_X, test_y)
yhat = mlp_model.predict(test_X)
recall = recall_score(test_y, yhat, average='weighted')
precision = precision_score(test_y, yhat, average='weighted')
print('정확도 :', accuracy)
print('재현율 :', recall)
print('정밀도 :', precision)
print('교차표\n', pd.crosstab(test_y, yhat, 
                           rownames=['실제'],
                           colnames=['예측']))
# Out:
# 정확도 : 0.8666666666666667
# 재현율 : 0.8666666666666667
# 정밀도 : 0.9047619047619048
# 교차표
#  예측  0  1  2
# 실제
# 0   5  0  0
# 1   0  3  2
# 2   0  0  5

# %% [markdown]
# # 3. 클래스 이용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', optimizer='adam'):
        # 모델 구성
#         model = Sequential()
#         model.add(Input(input_dim,))
#         model.add(Dense(50, activation=activation))
#         model.add(Dense(30, activation=activation))
#         model.add(Dense(3, activation='softmax'))
        model = Sequential([
            Input(input_dim,) ,
            Dense(50, activation=activation),
            Dense(30, activation=activation),
            Dense(3, activation='softmax')
        ])
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        return model

# %%
# %%time
# 모델
model = DNNClassifier.build(input_dim=4, activation='relu')
model.summary()
# 모델 학습
hist = model.fit(train_X, train_y,
                epochs=500,
                validation_split=0.2,
                verbose=0)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                250
#
#  dense_4 (Dense)             (None, 30)                1530
#
#  dense_5 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: total: 20.1 s
# Wall time: 15.4 s

# %%
loss, accuracy = model.evaluate(test_X, test_y)
loss, accuracy
# Out:
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0251 - accuracy: 1.0000
# (0.025134457275271416, 1.0)

# %% [markdown]
# # 4. 함수형 API 이용하기
# - 병렬처리 : 속도 높이려고
# - 레지듀얼블록(Residual block) : 모델의 성능을 높이려고(자연어처리,이미지처리)

# %%
# import
import numpy as np
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras import Model # 모델 생성(입력층과 출력층을 이용)
from tensorflow.keras.layers import Dense, Input, add # add :레지듀얼블록 
from tensorflow.keras.layers import concatenate # 병렬처리시

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %%
# 기존의 model 스타일 4 -> 50 -> 30 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=30, activation='relu')(dense1)
dense3 = Dense(units=3, activation='softmax')(dense2)
model = Model(inputs=input_, outputs=dense3)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=20,
         validation_split=0.2)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 4)]               0
#
#  dense_6 (Dense)             (None, 50)                250
#
#  dense_7 (Dense)             (None, 30)                1530
#
#  dense_8 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 0s 52ms/step - loss: 1.7125 - accuracy: 0.2963 - val_loss: 1.3008 - val_accuracy: 0.4815
# Epoch 2/20
# 4/4 [==============================] - 0s 11ms/step - loss: 1.3475 - accuracy: 0.2963 - val_loss: 1.1284 - val_accuracy: 0.5185
# Epoch 3/20
# 4/4 [==============================] - 0s 14ms/step - loss: 1.1105 - accuracy: 0.5000 - val_loss: 1.0205 - val_accuracy: 0.4815
# Epoch 4/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9903 - accuracy: 0.5278 - val_loss: 0.9394 - val_accuracy: 0.7037
# Epoch 5/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.9109 - accuracy: 0.6296 - val_loss: 0.8572 - val_accuracy: 0.5926
# Epoch 6/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8434 - accuracy: 0.5648 - val_loss: 0.7785 - val_accuracy: 0.7778
# Epoch 7/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7969 - accuracy: 0.6389 - val_loss: 0.7137 - val_accuracy: 0.7778
# Epoch 8/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7453 - accuracy: 0.6667 - val_loss: 0.6599 - val_accuracy: 0.9630
# Epoch 9/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6957 - accuracy: 0.9167 - val_loss: 0.6275 - val_accuracy: 0.7037
# Epoch 10/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6592 - accuracy: 0.6944 - val_loss: 0.6091 - val_accuracy: 0.7037
# Epoch 11/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6371 - accuracy: 0.6574 - val_loss: 0.5818 - val_accuracy: 0.7037
# Epoch 12/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6129 - accuracy: 0.6574 - val_loss: 0.5393 - val_accuracy: 0.7037
# Epoch 13/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5839 - accuracy: 0.6759 - val_loss: 0.5042 - val_accuracy: 0.7407
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5600 - accuracy: 0.8148 - val_loss: 0.4749 - val_accuracy: 0.8519
# Epoch 15/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5375 - accuracy: 0.8611 - val_loss: 0.4591 - val_accuracy: 0.7778
# Epoch 16/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5178 - accuracy: 0.8241 - val_loss: 0.4481 - val_accuracy: 0.7778
# Epoch 17/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5014 - accuracy: 0.8241 - val_loss: 0.4348 - val_accuracy: 0.7778
# Epoch 18/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4865 - accuracy: 0.8426 - val_loss: 0.4146 - val_accuracy: 0.8519
# Epoch 19/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4705 - accuracy: 0.8796 - val_loss: 0.3996 - val_accuracy: 0.8889
# Epoch 20/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4568 - accuracy: 0.9074 - val_loss: 0.3852 - val_accuracy: 0.8889

# %%
# 병렬처리
# 4 -> 160(50,80,30로 병렬처리) -> 32 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
# x = Dense(160, activation='relu')(input_)의 병렬처리
dense4 = Dense(32, activation='relu')(x)
output = Dense(3, activation='softmax')(dense4)
model = Model(inputs=input_, outputs=output)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 4)]          0           []
#
#  dense_9 (Dense)                (None, 50)           250         ['input_4[0][0]']
#
#  dense_10 (Dense)               (None, 80)           400         ['input_4[0][0]']
#
#  dense_11 (Dense)               (None, 30)           150         ['input_4[0][0]']
#
#  concatenate (Concatenate)      (None, 160)          0           ['dense_9[0][0]',
#                                                                   'dense_10[0][0]',
#                                                                   'dense_11[0][0]']
#
#  dense_12 (Dense)               (None, 32)           5152        ['concatenate[0][0]']
#
#  dense_13 (Dense)               (None, 3)            99          ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 6,051
# Trainable params: 6,051
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
# 레지듀얼블록(Residual Block):딥러닝에서 딥한 네트워크가 학습이 잘 되지 않을 때
# 4 -> 50 -> 50 ->(레지듀얼)-> 3
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(50, activation='relu')(dense1)
dense3 = add([dense1, dense2])
output = Dense(3, activation='softmax')(dense3)
model = Model(inputs=input_, outputs=output)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=500,
         validation_split=0.2, verbose=0)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 4)]          0           []
#
#  dense_14 (Dense)               (None, 50)           250         ['input_5[0][0]']
#
#  dense_15 (Dense)               (None, 50)           2550        ['dense_14[0][0]']
#
#  add (Add)                      (None, 50)           0           ['dense_14[0][0]',
#                                                                   'dense_15[0][0]']
#
#  dense_16 (Dense)               (None, 3)            153         ['add[0][0]']
#
# ==================================================================================================
# Total params: 2,953
# Trainable params: 2,953
# Non-trainable params: 0
# __________________________________________________________________________________________________
# CPU times: total: 18.8 s
# Wall time: 16 s

# %%
model.evaluate(test_X, test_y)
# Out:
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0368 - accuracy: 1.0000
# [0.03678681328892708, 1.0]
